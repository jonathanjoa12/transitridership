# %%
# %%time
# %run CapstoneExploratoryDataAnalysis.ipynb
# Out:
# <decorator-gen-62>:2: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
# Wall time: 418 ms
# <ipython-input-1-884cbe7c1f48>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['accessible'][i] = 0
# <ipython-input-1-884cbe7c1f48>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['accessible'][i] = 1
# <ipython-input-1-884cbe7c1f48>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import PowerTransformer

# %% [markdown]
# ## Preproccessing Regression Data

# %%
# Powertransformer
pt = PowerTransformer()
subway_data_regression = pd.DataFrame(pt.fit_transform(subway_data_regression))
# Out:
# C:\Users\jjoa\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2995: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %%
subway_data_regression
# Out:
#               0         1         2         3         4         5         6   \
# 0      -1.556901 -2.327372 -1.391997 -0.307557 -0.452663 -0.084964 -0.263016
# 1      -1.556901 -2.327372 -1.391997  0.693635 -0.452663 -0.084964 -0.263016
# 2      -1.556901 -2.327372 -1.391997  0.808057 -0.452663 -0.084964 -0.263016
# 3      -1.556901 -2.327372 -1.391997  0.169221 -0.452663 -0.084964 -0.263016
# 4      -1.556901 -2.327372 -1.391997  0.693008 -0.452663 -0.084964 -0.263016
# ...          ...       ...       ...       ...       ...       ...       ...
# 304996 -0.376302 -1.036180 -1.391997 -0.424388 -0.452663 -0.084964 -0.263016
# 304997 -0.376302 -1.036180 -1.391997 -0.493408 -0.452663 -0.084964 -0.263016
# 304998 -0.376302 -1.036180 -1.391997 -0.532266 -0.452663 -0.084964 -0.263016
# 304999 -0.376302 -1.036180 -1.391997 -0.364327 -0.452663 -0.084964 -0.263016
# 305000 -0.376302 -1.036180 -1.391997 -0.376231 -0.452663 -0.084964 -0.263016
#
# ...

# %%
# Setup our data
X = subway_data_regression[list(subway_data_regression.columns.drop([3]))]
y = subway_data_regression[3]

# %%
X
# Out:
#               0         1         2         4         5         6         7   \
# 0      -1.556901 -2.327372 -1.391997 -0.452663 -0.084964 -0.263016 -0.316796
# 1      -1.556901 -2.327372 -1.391997 -0.452663 -0.084964 -0.263016 -0.316796
# 2      -1.556901 -2.327372 -1.391997 -0.452663 -0.084964 -0.263016 -0.316796
# 3      -1.556901 -2.327372 -1.391997 -0.452663 -0.084964 -0.263016 -0.316796
# 4      -1.556901 -2.327372 -1.391997 -0.452663 -0.084964 -0.263016 -0.316796
# ...          ...       ...       ...       ...       ...       ...       ...
# 304996 -0.376302 -1.036180 -1.391997 -0.452663 -0.084964 -0.263016 -0.316796
# 304997 -0.376302 -1.036180 -1.391997 -0.452663 -0.084964 -0.263016 -0.316796
# 304998 -0.376302 -1.036180 -1.391997 -0.452663 -0.084964 -0.263016 -0.316796
# 304999 -0.376302 -1.036180 -1.391997 -0.452663 -0.084964 -0.263016 -0.316796
# 305000 -0.376302 -1.036180 -1.391997 -0.452663 -0.084964 -0.263016 -0.316796
#
# ...

# %%
y
# Out:
# 0        -0.307557
# 1         0.693635
# 2         0.808057
# 3         0.169221
# 4         0.693008
#             ...
# 304996   -0.424388
# 304997   -0.493408
# 304998   -0.532266
# 304999   -0.364327
# 305000   -0.376231
# Name: 3, Length: 305001, dtype: float64

# %%
(X_train, X_test, y_train, y_test) = train_test_split(X, y, random_state = 42)

# %%
X_train
# Out:
#               0         1         2         4         5         6         7   \
# 284094  0.638394  1.791169 -0.403161 -0.452663 -0.084964 -0.263016 -0.316796
# 265416  1.545234  1.049246 -1.391997 -0.452663 -0.084964 -0.263016 -0.316796
# 219053 -0.376302 -1.744652  1.301200 -0.452663 -0.084964 -0.263016 -0.316796
# 171015  0.638394 -0.526715 -0.403161 -0.452663 -0.084964 -0.263016  3.156606
# 237896  1.545234  0.654839  0.483505 -0.452663 -0.084964 -0.263016 -0.316796
# ...          ...       ...       ...       ...       ...       ...       ...
# 119879  0.638394  1.171227 -1.391997  2.209147 -0.084964 -0.263016 -0.316796
# 259178  1.545234  0.967957  1.301200 -0.452663 -0.084964 -0.263016 -0.316796
# 131932 -0.376302  1.803702 -1.391997 -0.452663 -0.084964 -0.263016 -0.316796
# 146867 -0.376302 -1.150991 -1.391997 -0.452663 -0.084964 -0.263016 -0.316796
# 121958 -0.376302 -1.523166  1.301200 -0.452663 -0.084964 -0.263016 -0.316796
#
# ...

# %%
y_train
# Out:
# 284094    1.009249
# 265416   -0.592930
# 219053   -0.519991
# 171015    0.623400
# 237896   -0.047551
#             ...
# 119879   -0.254179
# 259178    0.089800
# 131932   -0.169943
# 146867   -1.090078
# 121958    0.006532
# Name: 3, Length: 228750, dtype: float64

# %% [markdown]
# ## Preprocessing Time Series Data

# %%
import statsmodels.api as sm

# %%
X_train_time, X_test_time, y_train_time, y_test_time = train_test_split(subway_data_time_series.drop(columns = ['entries']),
                                                    subway_data_time_series['entries'],
                                                   shuffle = False,
                                                   test_size = .2)

# %%
X_train_time = sm.add_constant(X_train_time)
X_test_time = sm.add_constant(X_test_time)

# %%
X_train_time.dropna(inplace = True)
y_train_time = y_train_time[X_train_time.index]
